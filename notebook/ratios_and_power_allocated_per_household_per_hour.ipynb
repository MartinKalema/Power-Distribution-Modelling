# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('Demand_Supply.xlsx')
avg_data = pd.read_excel('avg_hh_demand_reformatted.xlsx')

# %%
data
# Out:
#     Hour  Avg_Power  Min_hh_demand  Max_hh_demand  Avg_hh_demand     Min_dd  \
# 0      1      12.83       0.011102       0.014835       0.013399   1.731989
# 1      2      11.03       0.010830       0.014130       0.012524   1.689420
# 2      3       9.54       0.010983       0.012746       0.011782   1.713343
# 3      4       8.57       0.013484       0.015639       0.014353   2.103440
# 4      5       8.35       0.014765       0.021185       0.017456   2.303382
# 5      6       8.53       0.019558       0.026088       0.022991   3.051051
# 6      7       9.77       0.016044       0.045760       0.028563   2.502833
# 7      8       9.48       0.037581       0.053780       0.045229   5.862669
# 8      9      16.17       0.047514       0.107262       0.077150   7.412261
# 9     10      14.58       0.052392       0.094908       0.070847   8.173202
# 10    11      19.58       0.034939       0.068235       0.049172   5.450542
# ...

# %%
avg_data
# Out:
#      avg_hh_dd_hour_1  avg_hh_dd_hour_2  avg_hh_dd_hour_3  avg_hh_dd_hour_4  \
# 0            0.012995          0.013878          0.012438          0.014692
# 1            0.013257          0.013381          0.010932          0.014402
# 2            0.013549          0.011576          0.013109          0.015300
# 3            0.011809          0.013472          0.012366          0.015141
# 4            0.013472          0.012306          0.010440          0.013002
# ..                ...               ...               ...               ...
# 151          0.012594          0.011812          0.010370          0.015629
# 152          0.013710          0.014025          0.012543          0.014001
# 153          0.014121          0.011356          0.012088          0.013598
# 154          0.014883          0.013028          0.013006          0.013545
# 155          0.012895          0.013529          0.013013          0.013270
#
# ...

# %%
# Calculate the sum of each column
column_sums = avg_data.sum()
column_sums
# Out:
# avg_hh_dd_hour_1      2.095385
# avg_hh_dd_hour_2      1.937031
# avg_hh_dd_hour_3      1.825329
# avg_hh_dd_hour_4      2.256337
# avg_hh_dd_hour_5      2.738343
# avg_hh_dd_hour_6      3.586944
# avg_hh_dd_hour_7      4.478080
# avg_hh_dd_hour_8      7.022690
# avg_hh_dd_hour_9     12.156753
# avg_hh_dd_hour_10    11.129634
# avg_hh_dd_hour_11     7.634445
# avg_hh_dd_hour_12     8.349934
# avg_hh_dd_hour_13     6.427702
# avg_hh_dd_hour_14     8.138677
# avg_hh_dd_hour_15     9.399729
# avg_hh_dd_hour_16    10.513753
# avg_hh_dd_hour_17     8.560629
# avg_hh_dd_hour_18    10.914663
# avg_hh_dd_hour_19    10.586345
# avg_hh_dd_hour_20     7.723423
# avg_hh_dd_hour_21     5.432109
# avg_hh_dd_hour_22     4.000389
# avg_hh_dd_hour_23     2.755163
# avg_hh_dd_hour_24     2.441967
# dtype: float64

# %%
# Divide each element by the sum of its column
ratios = avg_data.div(column_sums, axis=1)

# %%
# Rename columns
ratios = ratios.rename(columns={'avg_hh_dd_hour_1': 'ratio_hour_1', 
                                'avg_hh_dd_hour_2': 'ratio_hour_2', 
                                'avg_hh_dd_hour_3': 'ratio_hour_3', 
                                'avg_hh_dd_hour_4': 'ratio_hour_4', 
                                'avg_hh_dd_hour_5': 'ratio_hour_5', 
                                'avg_hh_dd_hour_6': 'ratio_hour_6', 
                                'avg_hh_dd_hour_7': 'ratio_hour_7', 
                                'avg_hh_dd_hour_8': 'ratio_hour_8', 
                                'avg_hh_dd_hour_9': 'ratio_hour_9', 
                                'avg_hh_dd_hour_10': 'ratio_hour_10', 
                                'avg_hh_dd_hour_11': 'ratio_hour_11', 
                                'avg_hh_dd_hour_12': 'ratio_hour_12', 
                                'avg_hh_dd_hour_13': 'ratio_hour_13', 
                                'avg_hh_dd_hour_14': 'ratio_hour_14', 
                                'avg_hh_dd_hour_15': 'ratio_hour_15', 
                                'avg_hh_dd_hour_16': 'ratio_hour_16', 
                                'avg_hh_dd_hour_17': 'ratio_hour_17', 
                                'avg_hh_dd_hour_18': 'ratio_hour_18', 
                                'avg_hh_dd_hour_19': 'ratio_hour_19', 
                                'avg_hh_dd_hour_20': 'ratio_hour_20', 
                                'avg_hh_dd_hour_21': 'ratio_hour_21', 
                                'avg_hh_dd_hour_22': 'ratio_hour_22', 
                                'avg_hh_dd_hour_23': 'ratio_hour_23', 
                                'avg_hh_dd_hour_24': 'ratio_hour_24', 
                                })

# %%
ratios
# Out:
#      ratio_hour_1  ratio_hour_2  ratio_hour_3  ratio_hour_4  ratio_hour_5  \
# 0        0.006202      0.007165      0.006814      0.006512      0.005848
# 1        0.006327      0.006908      0.005989      0.006383      0.006516
# 2        0.006466      0.005976      0.007182      0.006781      0.007047
# 3        0.005635      0.006955      0.006775      0.006711      0.006790
# 4        0.006429      0.006353      0.005719      0.005762      0.005658
# ..            ...           ...           ...           ...           ...
# 151      0.006010      0.006098      0.005681      0.006927      0.006822
# 152      0.006543      0.007241      0.006872      0.006205      0.006876
# 153      0.006739      0.005863      0.006622      0.006027      0.005875
# 154      0.007103      0.006726      0.007126      0.006003      0.006545
# 155      0.006154      0.006985      0.007129      0.005881      0.006180
#
#      ratio_hour_6  ratio_hour_7  ratio_hour_8  ratio_hour_9  ratio_hour_10  \
# ...

# %%
ratios.to_excel("ratios_per_household.xlsx", index=False)

# %%
ss_power = data['SS_Power'].values
ss_power
# Out:
# array([ 5.132,  4.412,  3.816,  3.428,  3.34 ,  3.412,  3.908,  3.792,
#         6.468,  5.832,  7.832,  7.892,  7.4  ,  8.868,  7.888,  7.592,
#         8.268,  9.384,  8.016,  9.764, 12.268, 10.984,  8.532,  6.188])

# %%
power_allocated_per_hour_per_household = ratios.mul(ss_power, axis=1)
# Changed to power_allocated_ratio

# %%
power_allocated_per_hour_per_household = power_allocated_per_hour_per_household.rename(columns={'ratio_hour_1' : 'power_per_hour_per_household_h1', 
                                                                                                'ratio_hour_2' : 'power_per_hour_per_household_h2',
                                                                                                'ratio_hour_3' : 'power_per_hour_per_household_h3',
                                                                                                'ratio_hour_4' : 'power_per_hour_per_household_h4',
                                                                                                'ratio_hour_5' : 'power_per_hour_per_household_h5',
                                                                                                'ratio_hour_6' : 'power_per_hour_per_household_h6',
                                                                                                'ratio_hour_7' : 'power_per_hour_per_household_h7',
                                                                                                'ratio_hour_8' : 'power_per_hour_per_household_h8',
                                                                                                'ratio_hour_9' : 'power_per_hour_per_household_h9',
                                                                                                'ratio_hour_10' : 'power_per_hour_per_household_h10',
                                                                                                'ratio_hour_11' : 'power_per_hour_per_household_h11',
                                                                                                'ratio_hour_12' : 'power_per_hour_per_household_h12',
                                                                                                'ratio_hour_13' : 'power_per_hour_per_household_h13',
                                                                                                'ratio_hour_14' : 'power_per_hour_per_household_h14',
                                                                                                'ratio_hour_15' : 'power_per_hour_per_household_h15',
                                                                                                'ratio_hour_16' : 'power_per_hour_per_household_h16',
                                                                                                'ratio_hour_17' : 'power_per_hour_per_household_h17',
                                                                                                'ratio_hour_18' : 'power_per_hour_per_household_h18',
                                                                                                'ratio_hour_19' : 'power_per_hour_per_household_h19',
                                                                                                'ratio_hour_20' : 'power_per_hour_per_household_h20',
                                                                                                'ratio_hour_21' : 'power_per_hour_per_household_h21',
                                                                                                'ratio_hour_22' : 'power_per_hour_per_household_h22',
                                                                                                'ratio_hour_23' : 'power_per_hour_per_household_h23',
                                                                                                'ratio_hour_24' : 'power_per_hour_per_household_h24',
                                                                                                
                                                                                                })

# %%
# power allocated by ratio
# power allocated by demand using min_hh_dd, min(power allocated by ratio, min_hh_dd)
# power allocated by demand using max_hh_dd, min(power allocated by ratio, max_hh_dd)

# unmet_demand = household_demand - power_allocated_by_demand
# unmet_demand = household_demand - power_allocated_by_demand
power_allocated_per_hour_per_household
# Out:
#      power_per_hour_per_household_h1  power_per_hour_per_household_h2  \
# 0                           0.031828                         0.031611
# 1                           0.032470                         0.030478
# 2                           0.033184                         0.026368
# 3                           0.028921                         0.030685
# 4                           0.032995                         0.028029
# ..                               ...                              ...
# 151                         0.030844                         0.026905
# 152                         0.033579                         0.031945
# 153                         0.034585                         0.025866
# 154                         0.036450                         0.029675
# 155                         0.031582                         0.030816
#
#      power_per_hour_per_household_h3  power_per_hour_per_household_h4  \
# ...

# %%
power_allocated_per_hour_per_household.to_excel("power_per_hour_per_household.xlsx", index=False)
# changed to power_allocated_ratio
