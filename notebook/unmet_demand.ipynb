# %%
import numpy as np
import pandas as pd

# %%
min_hh_dd = pd.read_excel('min_hh_demand_reformatted.xlsx')
max_hh_dd = pd.read_excel('max_hh_demand_reformatted.xlsx')
power_power_hour_per_household = pd.read_excel('power_per_hour_per_household.xlsx')

# %%
power_power_hour_per_household
# Out:
#      power_per_hour_per_household_h1  power_per_hour_per_household_h2  \
# 0                           0.031828                         0.031611
# 1                           0.032470                         0.030478
# 2                           0.033184                         0.026368
# 3                           0.028921                         0.030685
# 4                           0.032995                         0.028029
# ..                               ...                              ...
# 151                         0.030844                         0.026905
# 152                         0.033579                         0.031945
# 153                         0.034585                         0.025866
# 154                         0.036450                         0.029675
# 155                         0.031582                         0.030816
#
#      power_per_hour_per_household_h3  power_per_hour_per_household_h4  \
# ...

# %%
min_hh_dd
# Out:
#      min_hh_dd_hour_1  min_hh_dd_hour_2  min_hh_dd_hour_3  min_hh_dd_hour_4  \
# 0            0.010768          0.012001          0.011594          0.013803
# 1            0.010985          0.011571          0.010191          0.013530
# 2            0.011227          0.010011          0.012221          0.014374
# 3            0.009785          0.011650          0.011528          0.014225
# 4            0.011163          0.010641          0.009732          0.012215
# ..                ...               ...               ...               ...
# 151          0.010435          0.010214          0.009667          0.014683
# 152          0.011361          0.012128          0.011693          0.013153
# 153          0.011701          0.009820          0.011268          0.012775
# 154          0.012332          0.011266          0.012125          0.012725
# 155          0.010685          0.011699          0.012131          0.012467
#
# ...

# %%
max_hh_dd
# Out:
#      max_hh_dd_hour_1  max_hh_dd_hour_2  max_hh_dd_hour_3  max_hh_dd_hour_4  \
# 0            0.014388          0.015659          0.013455          0.016010
# 1            0.014678          0.015097          0.011827          0.015693
# 2            0.015001          0.013061          0.014182          0.016672
# 3            0.013074          0.015200          0.013378          0.016499
# 4            0.014916          0.013884          0.011294          0.014167
# ..                ...               ...               ...               ...
# 151          0.013944          0.013327          0.011218          0.017031
# 152          0.015180          0.015824          0.013570          0.015256
# 153          0.015635          0.012813          0.013077          0.014817
# 154          0.016478          0.014699          0.014071          0.014759
# 155          0.014277          0.015265          0.014078          0.014460
#
# ...

# %%
unmet_demand_from_min_hh_dd = min_hh_dd.values - power_power_hour_per_household.values

# %%
unmet_demand_from_min_hh_dd.shape
# Out:
# (156, 24)

# %%
column_names = ['unmet_demand_from_min_h1',
                'unmet_demand_from_min_h2',
                'unmet_demand_from_min_h3',
                'unmet_demand_from_min_h4',
                'unmet_demand_from_min_h5',
                'unmet_demand_from_min_h6',
                'unmet_demand_from_min_h7',
                'unmet_demand_from_min_h8',
                'unmet_demand_from_min_h9',
                'unmet_demand_from_min_h10',
                'unmet_demand_from_min_h11',
                'unmet_demand_from_min_h12',
                'unmet_demand_from_min_h13',
                'unmet_demand_from_min_h14',
                'unmet_demand_from_min_h15',
                'unmet_demand_from_min_h16',
                'unmet_demand_from_min_h17',
                'unmet_demand_from_min_h18',
                'unmet_demand_from_min_h19', 
                'unmet_demand_from_min_h20',
                'unmet_demand_from_min_h21',
                'unmet_demand_from_min_h22',
                'unmet_demand_from_min_h23',
                'unmet_demand_from_min_h24']

# %%
unmet_demand_from_min_hh_dd = pd.DataFrame(unmet_demand_from_min_hh_dd, columns=column_names)

# %%
unmet_demand_from_min_hh_dd
# Out:
#      unmet_demand_from_min_h1  unmet_demand_from_min_h2  \
# 0                   -0.021059                 -0.019610
# 1                   -0.021484                 -0.018907
# 2                   -0.021957                 -0.016357
# 3                   -0.019136                 -0.019036
# 4                   -0.021832                 -0.017388
# ..                        ...                       ...
# 151                 -0.020409                 -0.016690
# 152                 -0.022218                 -0.019817
# 153                 -0.022884                 -0.016046
# 154                 -0.024118                 -0.018409
# 155                 -0.020897                 -0.019117
#
#      unmet_demand_from_min_h3  unmet_demand_from_min_h4  \
# 0                   -0.014407                 -0.008519
# 1                   -0.012664                 -0.008350
# 2                   -0.015185                 -0.008871
# 3                   -0.014325                 -0.008779
# ...

# %%
unmet_demand_from_min_hh_dd.to_excel("unmet_demand_from_min_hh_dd.xlsx", index=False)

# %%
unmet_demand_from_max_hh_dd = max_hh_dd.values - power_power_hour_per_household.values

# %%
unmet_demand_from_max_hh_dd.shape
# Out:
# (156, 24)

# %%
column_names = ['unmet_demand_from_max_h1',
                'unmet_demand_from_max_h2',
                'unmet_demand_from_max_h3',
                'unmet_demand_from_max_h4',
                'unmet_demand_from_max_h5',
                'unmet_demand_from_max_h6',
                'unmet_demand_from_max_h7',
                'unmet_demand_from_max_h8',
                'unmet_demand_from_max_h9',
                'unmet_demand_from_max_h10',
                'unmet_demand_from_max_h11',
                'unmet_demand_from_max_h12',
                'unmet_demand_from_max_h13',
                'unmet_demand_from_max_h14',
                'unmet_demand_from_max_h15',
                'unmet_demand_from_max_h16',
                'unmet_demand_from_max_h17',
                'unmet_demand_from_max_h18',
                'unmet_demand_from_max_h19', 
                'unmet_demand_from_max_h20',
                'unmet_demand_from_max_h21',
                'unmet_demand_from_max_h22',
                'unmet_demand_from_max_h23',
                'unmet_demand_from_max_h24']

# %%
unmet_demand_from_max_hh_dd = pd.DataFrame(unmet_demand_from_max_hh_dd, columns=column_names)

# %%
unmet_demand_from_max_hh_dd
# Out:
#      unmet_demand_from_max_h1  unmet_demand_from_max_h2  \
# 0                   -0.017439                 -0.015952
# 1                   -0.017791                 -0.015381
# 2                   -0.018182                 -0.013307
# 3                   -0.015847                 -0.015485
# 4                   -0.018079                 -0.014145
# ..                        ...                       ...
# 151                 -0.016901                 -0.013577
# 152                 -0.018399                 -0.016121
# 153                 -0.018950                 -0.013053
# 154                 -0.019972                 -0.014975
# 155                 -0.017305                 -0.015551
#
#      unmet_demand_from_max_h3  unmet_demand_from_max_h4  \
# 0                   -0.012546                 -0.006312
# 1                   -0.011028                 -0.006187
# 2                   -0.013224                 -0.006573
# 3                   -0.012475                 -0.006505
# ...

# %%
unmet_demand_from_max_hh_dd.to_excel("unmet_demand_from_max_hh_dd.xlsx", index=False)
