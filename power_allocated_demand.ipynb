# %%
import pandas as pd
import numpy as np

# %%
from IPython.display import display

display.max_columns = None  
display.max_rows = None   

np.set_printoptions(threshold=np.inf)

# %%
power_allocated_ratio = pd.read_excel('power_allocated_ratio.xlsx')
max_hh_dd = pd.read_excel('max_hh_demand_reformatted.xlsx')
min_hh_dd = pd.read_excel('min_hh_demand_reformatted.xlsx')

# %%
power_allocated_ratio.values
# Out:
# array([[0.03182767, 0.03161109, 0.02600167, 0.02232175, 0.01953367,
#         0.02006426, 0.02228293, 0.02656831, 0.04204389, 0.03897825,
#         0.04464012, 0.05594718, 0.05121777, 0.0526553 , 0.04725275,
#         0.04499445, 0.05075673, 0.06092182, 0.05081654, 0.05952713,
#         0.08118576, 0.06421456, 0.05188414, 0.03843799],
#        [0.03246979, 0.0304778 , 0.02285499, 0.02187994, 0.02176362,
#         0.01948929, 0.02557002, 0.02249089, 0.03676288, 0.04112386,
#         0.05608145, 0.05399829, 0.04520898, 0.05109876, 0.05342145,
#         0.04799497, 0.04842777, 0.06049189, 0.04588744, 0.06882328,
#         0.07448613, 0.07303868, 0.05214058, 0.03990294],
#        [0.03318365, 0.02636793, 0.02740614, 0.0232453 , 0.0235372 ,
#         0.02394222, 0.02551232, 0.02689477, 0.03699381, 0.03441561,
#         0.04493846, 0.04816937, 0.04616595, 0.05345633, 0.05519571,
#         0.04702031, 0.0504588 , 0.06118258, 0.04720832, 0.06721213,
# ...

# %%
min_hh_dd.values
# Out:
# array([[0.01076819, 0.01200107, 0.01159449, 0.01380286, 0.01354631,
#         0.01794328, 0.0143422 , 0.04088393, 0.04866755, 0.05500866,
#         0.03091926, 0.05260159, 0.04124641, 0.03130225, 0.04707986,
#         0.05163881, 0.04707744, 0.06572936, 0.0547874 , 0.02887369,
#         0.03053482, 0.01905833, 0.01615019, 0.01304208],
#        [0.01098544, 0.01157082, 0.01019134, 0.01352965, 0.01509275,
#         0.01742909, 0.01645791, 0.03460951, 0.04255457, 0.05803668,
#         0.03884391, 0.05076924, 0.03640745, 0.03037693, 0.05322599,
#         0.05508243, 0.0449173 , 0.06526549, 0.04947314, 0.03338279,
#         0.02801502, 0.02167726, 0.01623001, 0.01353914],
#        [0.01122696, 0.01001052, 0.01222076, 0.01437394, 0.0163227 ,
#         0.02141131, 0.01642077, 0.0413863 , 0.04282187, 0.04856956,
#         0.0311259 , 0.04528889, 0.03717811, 0.03177844, 0.05499376,
#         0.05396384, 0.04680111, 0.06601068, 0.05089723, 0.03260131,
# ...

# %%
max_hh_dd.values
# Out:
# array([[0.01438821, 0.01565863, 0.01345521, 0.01600955, 0.0194364 ,
#         0.02393417, 0.04090667, 0.05850642, 0.10986478, 0.09964756,
#         0.06038371, 0.0646918 , 0.04739652, 0.06559203, 0.06516239,
#         0.07361013, 0.05741933, 0.07479914, 0.08139943, 0.06237634,
#         0.04029443, 0.0267772 , 0.01727162, 0.01768076],
#        [0.01467849, 0.01509725, 0.01182687, 0.01569267, 0.02165525,
#         0.0232483 , 0.04694107, 0.04952748, 0.09606499, 0.10513278,
#         0.07586014, 0.0624383 , 0.04183603, 0.06365307, 0.07366913,
#         0.07851894, 0.05478466, 0.07427127, 0.07350386, 0.07211744,
#         0.03696924, 0.03045682, 0.01735698, 0.01835461],
#        [0.0150012 , 0.01306142, 0.01418198, 0.01667193, 0.02341999,
#         0.0285601 , 0.04683515, 0.05922532, 0.09666843, 0.08798321,
#         0.06078727, 0.05569831, 0.04272161, 0.06658986, 0.07611587,
#         0.07692442, 0.0570823 , 0.07511929, 0.07561968, 0.07042918,
# ...

# %% [markdown]
# ## Power allocated demand from min_hh_dd

# %%
power_allocated_demand_from_min_hh_dd = np.minimum(min_hh_dd.values, power_allocated_ratio.values)

# %%
power_allocated_demand_from_min_hh_dd
# Out:
# array([[0.01076819, 0.01200107, 0.01159449, 0.01380286, 0.01354631,
#         0.01794328, 0.0143422 , 0.02656831, 0.04204389, 0.03897825,
#         0.03091926, 0.05260159, 0.04124641, 0.03130225, 0.04707986,
#         0.04499445, 0.04707744, 0.06092182, 0.05081654, 0.02887369,
#         0.03053482, 0.01905833, 0.01615019, 0.01304208],
#        [0.01098544, 0.01157082, 0.01019134, 0.01352965, 0.01509275,
#         0.01742909, 0.01645791, 0.02249089, 0.03676288, 0.04112386,
#         0.03884391, 0.05076924, 0.03640745, 0.03037693, 0.05322599,
#         0.04799497, 0.0449173 , 0.06049189, 0.04588744, 0.03338279,
#         0.02801502, 0.02167726, 0.01623001, 0.01353914],
#        [0.01122696, 0.01001052, 0.01222076, 0.01437394, 0.0163227 ,
#         0.02141131, 0.01642077, 0.02689477, 0.03699381, 0.03441561,
#         0.0311259 , 0.04528889, 0.03717811, 0.03177844, 0.05499376,
#         0.04702031, 0.04680111, 0.06118258, 0.04720832, 0.03260131,
# ...

# %%
columns = ['power_allocated_demand_from_min_hour_1',
           'power_allocated_demand_from_min_hour_2',
           'power_allocated_demand_from_min_hour_3',
           'power_allocated_demand_from_min_hour_4',
           'power_allocated_demand_from_min_hour_5',
           'power_allocated_demand_from_min_hour_6',
           'power_allocated_demand_from_min_hour_7',
           'power_allocated_demand_from_min_hour_8',
           'power_allocated_demand_from_min_hour_9',
           'power_allocated_demand_from_min_hour_10',
           'power_allocated_demand_from_min_hour_11',
           'power_allocated_demand_from_min_hour_12',
           'power_allocated_demand_from_min_hour_13',
           'power_allocated_demand_from_min_hour_14',
           'power_allocated_demand_from_min_hour_15',
           'power_allocated_demand_from_min_hour_16',
           'power_allocated_demand_from_min_hour_17',
           'power_allocated_demand_from_min_hour_18',
           'power_allocated_demand_from_min_hour_19',
           'power_allocated_demand_from_min_hour_20',
           'power_allocated_demand_from_min_hour_21',
           'power_allocated_demand_from_min_hour_22',
           'power_allocated_demand_from_min_hour_23',
           'power_allocated_demand_from_min_hour_24']

# %%
power_allocated_demand_from_min_hh_dd = pd.DataFrame(power_allocated_demand_from_min_hh_dd, columns=columns)

# %%
power_allocated_demand_from_min_hh_dd
# Out:
#      power_allocated_demand_from_min_hour_1  \
# 0                                  0.010768
# 1                                  0.010985
# 2                                  0.011227
# 3                                  0.009785
# 4                                  0.011163
# ..                                      ...
# 151                                0.010435
# 152                                0.011361
# 153                                0.011701
# 154                                0.012332
# 155                                0.010685
#
#      power_allocated_demand_from_min_hour_2  \
# 0                                  0.012001
# 1                                  0.011571
# 2                                  0.010011
# 3                                  0.011650
# 4                                  0.010641
# ..                                      ...
# 151                                0.010214
# 152                                0.012128
# ...

# %%
power_allocated_demand_from_min_hh_dd.to_excel('power_allocated_demand_from_min_hh_dd.xlsx', index=False)

# %% [markdown]
# ## Power allocated demand from max_hh_dd

# %%
power_allocated_demand_from_max_hh_dd = np.minimum(max_hh_dd.values, power_allocated_ratio.values)

# %%
power_allocated_demand_from_max_hh_dd
# Out:
# array([[0.01438821, 0.01565863, 0.01345521, 0.01600955, 0.0194364 ,
#         0.02006426, 0.02228293, 0.02656831, 0.04204389, 0.03897825,
#         0.04464012, 0.05594718, 0.04739652, 0.0526553 , 0.04725275,
#         0.04499445, 0.05075673, 0.06092182, 0.05081654, 0.05952713,
#         0.04029443, 0.0267772 , 0.01727162, 0.01768076],
#        [0.01467849, 0.01509725, 0.01182687, 0.01569267, 0.02165525,
#         0.01948929, 0.02557002, 0.02249089, 0.03676288, 0.04112386,
#         0.05608145, 0.05399829, 0.04183603, 0.05109876, 0.05342145,
#         0.04799497, 0.04842777, 0.06049189, 0.04588744, 0.06882328,
#         0.03696924, 0.03045682, 0.01735698, 0.01835461],
#        [0.0150012 , 0.01306142, 0.01418198, 0.01667193, 0.02341999,
#         0.02394222, 0.02551232, 0.02689477, 0.03699381, 0.03441561,
#         0.04493846, 0.04816937, 0.04272161, 0.05345633, 0.05519571,
#         0.04702031, 0.0504588 , 0.06118258, 0.04720832, 0.06721213,
# ...

# %%
columns = ['power_allocated_demand_from_max_hour_1',
           'power_allocated_demand_from_max_hour_2',
           'power_allocated_demand_from_max_hour_3',
           'power_allocated_demand_from_max_hour_4',
           'power_allocated_demand_from_max_hour_5',
           'power_allocated_demand_from_max_hour_6',
           'power_allocated_demand_from_max_hour_7',
           'power_allocated_demand_from_max_hour_8',
           'power_allocated_demand_from_max_hour_9',
           'power_allocated_demand_from_max_hour_10',
           'power_allocated_demand_from_max_hour_11',
           'power_allocated_demand_from_max_hour_12',
           'power_allocated_demand_from_max_hour_13',
           'power_allocated_demand_from_max_hour_14',
           'power_allocated_demand_from_max_hour_15',
           'power_allocated_demand_from_max_hour_16',
           'power_allocated_demand_from_max_hour_17',
           'power_allocated_demand_from_max_hour_18',
           'power_allocated_demand_from_max_hour_19',
           'power_allocated_demand_from_max_hour_20',
           'power_allocated_demand_from_max_hour_21',
           'power_allocated_demand_from_max_hour_22',
           'power_allocated_demand_from_max_hour_23',
           'power_allocated_demand_from_max_hour_24']

# %%
power_allocated_demand_from_max_hh_dd = pd.DataFrame(power_allocated_demand_from_max_hh_dd, columns=columns)

# %%
power_allocated_demand_from_max_hh_dd
# Out:
#      power_allocated_demand_from_max_hour_1  \
# 0                                  0.014388
# 1                                  0.014678
# 2                                  0.015001
# 3                                  0.013074
# 4                                  0.014916
# ..                                      ...
# 151                                0.013944
# 152                                0.015180
# 153                                0.015635
# 154                                0.016478
# 155                                0.014277
#
#      power_allocated_demand_from_max_hour_2  \
# 0                                  0.015659
# 1                                  0.015097
# 2                                  0.013061
# 3                                  0.015200
# 4                                  0.013884
# ..                                      ...
# 151                                0.013327
# 152                                0.015824
# ...

# %%
power_allocated_demand_from_max_hh_dd.to_excel('power_allocated_demand_from_max_hh_dd.xlsx', index=False)
